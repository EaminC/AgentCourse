# %% [markdown]
# ## 1. feedparser - RSS 解析

# %%
# !pip install feedparser
# Out:
# Collecting feedparser
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Using cached feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6089 sha256=a5174e36194eeaf695ad9ce72c93da5eecd5f9c0c9df7856dcc82fbbf565ec11
#   Stored in directory: /Users/eamin/Library/Caches/pip/wheels/3d/4d/ef/37cdccc18d6fd7e0dd7817dcdf9146d4d6789c32a227a28134
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [feedparser]
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0

# %%
import feedparser

# feedparser.parse(url) - 解析 RSS 订阅源
rss_url = "http://news.baidu.com/n?cmd=4&class=civilnews&tn=rss"
feed = feedparser.parse(rss_url)

print(feed)
print(feed.entries)
# Out:
# {'bozo': True, 'entries': [{'title': '捞舆｜优绩主义下的家校合作，该如何纠偏？', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '捞舆｜优绩主义下的家校合作，该如何纠偏？'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844190104142809783'}], 'link': 'http://baijiahao.baidu.com/s?id=1844190104142809783', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844190104142809783" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft10.baidu.com%2Fit%2Fu%3D2427192796%2C277114015%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D54AA92F04833ABDA4639311D0300B040&amp;fm=30" /></a><br />□迟鸥近年来，教育惩戒相关新闻时常引发争议，家校冲突不时登上热搜。除去极端个案，作为以育人为共同目标的合作主体，家校间本不该如此。但当下的现实是，教育相关热点事件通常以各方立场不变、情绪暂消的方式隐退', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '<a href="http://baijiahao.baidu.com/s?id=1844190104142809783" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft10.baidu.com%2Fit%2Fu%3D2427192796%2C277114015%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D54AA92F04833ABDA4639311D0300B040&amp;fm=30" /></a><br />□迟鸥近年来，教育惩戒相关新闻时常引发争议，家校冲突不时登上热搜。除去极端个案，作为以育人为共同目标的合作主体，家校间本不该如此。但当下的现实是，教育相关热点事件通常以各方立场不变、情绪暂消的方式隐退'}, 'published': '2025-11-09T23:03:35.000Z', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=9, tm_hour=23, tm_min=3, tm_sec=35, tm_wday=6, tm_yday=313, tm_isdst=0), 'source': {}, 'authors': [{}], 'author': ''}, {'title': '树外附小家长说：长在家长心田的口碑', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '树外附小家长说：长在家长心田的口碑'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844312032551754504'}], 'link': 'http://baijiahao.baidu.com/s?id=1844312032551754504', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844312032551754504" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D603638932%2C277227568%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3DF3E827F10D4260CE569410590300C0F0&amp;fm=30" /></a><br />大象新闻记者李书恒通讯员王丽霞马岩/文图马克思曾在《资本论》一书对“价值”二字做过深刻的阐述，详细解读了商品的使用价值和价值二因素的自然属性和社会属性。走进郑州市树人外国语学校附属小学(以下简称树外附', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '<a href="http://baijiahao.baidu.com/s?id=1844312032551754504" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D603638932%2C277227568%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3DF3E827F10D4260CE569410590300C0F0&amp;fm=30" /></a><br />大象新闻记者李书恒通讯员王丽霞马岩/文图马克思曾在《资本论》一书对“价值”二字做过深刻的阐述，详细解读了商品的使用价值和价值二因素的自然属性和社会属性。走进郑州市树人外国语学校附属小学(以下简称树外附'}, 'published': '2025-11-09T23:03:35.000Z', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=9, tm_hour=23, tm_min=3, tm_sec=35, tm_wday=6, tm_yday=313, tm_isdst=0), 'source': {}, 'authors': [{}], 'author': ''}, {'title': '以高质量党建引领高质量发展！贵阳康养职业大学建设特..', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '以高质量党建引领高质量发展！贵阳康养职业大学建设特..'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844399044002473581'}], 'link': 'http://baijiahao.baidu.com/s?id=1844399044002473581', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844399044002473581" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D2332516664%2C277315459%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D4940C1194E727A88449D75C6010070B0&amp;fm=30" /></a><br />在新时代职业教育改革发展的浪潮中，贵阳康养职业大学凭借鲜明的医康养特色和扎实的办学实践，逐步成长为区域职业本科教育领域的一面旗帜。学校把党的建设贯穿办学治校全过程，深入实施党建领航工程，推动党建与教育', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://new ...
# [{'title': '捞舆｜优绩主义下的家校合作，该如何纠偏？', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '捞舆｜优绩主义下的家校合作，该如何纠偏？'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844190104142809783'}], 'link': 'http://baijiahao.baidu.com/s?id=1844190104142809783', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844190104142809783" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft10.baidu.com%2Fit%2Fu%3D2427192796%2C277114015%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D54AA92F04833ABDA4639311D0300B040&amp;fm=30" /></a><br />□迟鸥近年来，教育惩戒相关新闻时常引发争议，家校冲突不时登上热搜。除去极端个案，作为以育人为共同目标的合作主体，家校间本不该如此。但当下的现实是，教育相关热点事件通常以各方立场不变、情绪暂消的方式隐退', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '<a href="http://baijiahao.baidu.com/s?id=1844190104142809783" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft10.baidu.com%2Fit%2Fu%3D2427192796%2C277114015%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D54AA92F04833ABDA4639311D0300B040&amp;fm=30" /></a><br />□迟鸥近年来，教育惩戒相关新闻时常引发争议，家校冲突不时登上热搜。除去极端个案，作为以育人为共同目标的合作主体，家校间本不该如此。但当下的现实是，教育相关热点事件通常以各方立场不变、情绪暂消的方式隐退'}, 'published': '2025-11-09T23:03:35.000Z', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=9, tm_hour=23, tm_min=3, tm_sec=35, tm_wday=6, tm_yday=313, tm_isdst=0), 'source': {}, 'authors': [{}], 'author': ''}, {'title': '树外附小家长说：长在家长心田的口碑', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '树外附小家长说：长在家长心田的口碑'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844312032551754504'}], 'link': 'http://baijiahao.baidu.com/s?id=1844312032551754504', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844312032551754504" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D603638932%2C277227568%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3DF3E827F10D4260CE569410590300C0F0&amp;fm=30" /></a><br />大象新闻记者李书恒通讯员王丽霞马岩/文图马克思曾在《资本论》一书对“价值”二字做过深刻的阐述，详细解读了商品的使用价值和价值二因素的自然属性和社会属性。走进郑州市树人外国语学校附属小学(以下简称树外附', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '<a href="http://baijiahao.baidu.com/s?id=1844312032551754504" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D603638932%2C277227568%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3DF3E827F10D4260CE569410590300C0F0&amp;fm=30" /></a><br />大象新闻记者李书恒通讯员王丽霞马岩/文图马克思曾在《资本论》一书对“价值”二字做过深刻的阐述，详细解读了商品的使用价值和价值二因素的自然属性和社会属性。走进郑州市树人外国语学校附属小学(以下简称树外附'}, 'published': '2025-11-09T23:03:35.000Z', 'published_parsed': time.struct_time(tm_year=2025, tm_mon=11, tm_mday=9, tm_hour=23, tm_min=3, tm_sec=35, tm_wday=6, tm_yday=313, tm_isdst=0), 'source': {}, 'authors': [{}], 'author': ''}, {'title': '以高质量党建引领高质量发展！贵阳康养职业大学建设特..', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class=civilnews&tn=rss', 'value': '以高质量党建引领高质量发展！贵阳康养职业大学建设特..'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'http://baijiahao.baidu.com/s?id=1844399044002473581'}], 'link': 'http://baijiahao.baidu.com/s?id=1844399044002473581', 'summary': '<a href="http://baijiahao.baidu.com/s?id=1844399044002473581" target="_blank"><img border="0" src="http://t1.baidu.com/it/u=http%3A%2F%2Ft12.baidu.com%2Fit%2Fu%3D2332516664%2C277315459%26fm%3D30%26app%3D106%26f%3DJPEG%3Fw%3D312%26h%3D208%26s%3D4940C1194E727A88449D75C6010070B0&amp;fm=30" /></a><br />在新时代职业教育改革发展的浪潮中，贵阳康养职业大学凭借鲜明的医康养特色和扎实的办学实践，逐步成长为区域职业本科教育领域的一面旗帜。学校把党的建设贯穿办学治校全过程，深入实施党建领航工程，推动党建与教育', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://news.baidu.com/n?cmd=4&class= ...

# %%
import feedparser

# feedparser.parse(url) - 解析 RSS 订阅源
rss_url = "http://news.baidu.com/n?cmd=4&class=civilnews&tn=rss"
feed = feedparser.parse(rss_url)

# feed.entries - 新闻条目列表
print(f"新闻数量: {len(feed.entries)}")

# entry.title - 新闻标题
# entry.link - 新闻链接
if len(feed.entries) > 0:
    entry = feed.entries[0] # 这个 0 是索引的意思
    print(f"标题: {entry.title}")
    print(f"链接: {entry.link}")
# Out:
# 新闻数量: 31
# 标题: 22岁大学生反复陷入自我否定，心理健康亮起红灯｜听..
# 链接: http://baijiahao.baidu.com/s?id=1844477152770817617

# %% [markdown]
# ## 2. requests - HTTP 请求

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl (208 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [requests]
# Successfully installed certifi-2025.10.5 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 urllib3-2.5.0

# %%
import requests

# requests.get(url, timeout=10) - 发送 GET 请求
url = "https://www.example.com"
response = requests.get(url, timeout=10)

# response.encoding - 设置编码
response.encoding = response.apparent_encoding

# response.text - 获取响应文本内容
html = response.text
print(html)
print(f"网页内容长度: {len(html)} 字符")
# Out:
# <!doctype html><html lang="en"><head><title>Example Domain</title><meta name="viewport" content="width=device-width, initial-scale=1"><style>body{background:#eee;width:60vw;margin:15vh auto;font-family:system-ui,sans-serif}h1{font-size:1.5em}div{opacity:0.8}a:link,a:visited{color:#348}</style><body><div><h1>Example Domain</h1><p>This domain is for use in documentation examples without needing permission. Avoid use in operations.<p><a href="https://iana.org/domains/example">Learn more</a></div></body></html>
#
# 网页内容长度: 513 字符

# %% [markdown]
# ## 3. BeautifulSoup - HTML 解析

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.14.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading beautifulsoup4-4.14.2-py3-none-any.whl (106 kB)
# Downloading soupsieve-2.8-py3-none-any.whl (36 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, soupsieve, beautifulsoup4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [beautifulsoup4]
# Successfully installed beautifulsoup4-4.14.2 soupsieve-2.8 typing-extensions-4.15.0

# %%
from bs4 import BeautifulSoup

# BeautifulSoup(html, "html.parser") - 创建解析对象
html = "<html><body><p>段落1</p><p>段落2</p></body></html>"
soup = BeautifulSoup(html, "html.parser")

# soup.find_all("p") - 查找所有 <p> 标签
paragraphs = soup.find_all("p")
print(f"找到 {len(paragraphs)} 个段落")

# p.get_text(strip=True) - 获取标签内的文本，strip=True 去除首尾空白
for p in paragraphs:
    text = p.get_text(strip=True)
    print(f"  段落: {text}")
# Out:
# 找到 2 个段落
#   段落: 段落1
#   段落: 段落2

# %%
html = open("example_complex.html", "r").read()
soup = BeautifulSoup(html, "html.parser")
# soup.find_all("p") - 查找所有 <p> 标签
paragraphs = soup.find_all("p")
print(f"找到 {len(paragraphs)} 个段落")

# p.get_text(strip=True) - 获取标签内的文本，strip=True 去除首尾空白
for p in paragraphs:
    text = p.get_text(strip=True)
    print(f"  段落: {text}")
# Out:
# 找到 8 个段落
#   段落: 人工智能技术在近年来取得了突破性进展，各大科技公司都在加大投入。
#   段落: 机器学习算法不断优化，深度学习模型在图像识别、自然语言处理等领域表现出色。
#   段落: 专家预测，未来五年内，AI 将在更多行业得到广泛应用。
#   段落: 世界杯预选赛将于下个月正式拉开帷幕，各支球队都在积极备战。
#   段落: 主教练表示，球队已经做好了充分准备，有信心取得好成绩。
#   段落: 广告：欢迎使用我们的产品
#   段落: 版权所有 © 2025 新闻网站
#   段落: ICP备案号：12345678

# %% [markdown]
# ## 4. os - 文件系统操作

# %%
import os

# os.path.exists(path) - 检查文件/文件夹是否存在
path = "data"
if os.path.exists(path):
    print(f"{path} 存在")
else:
    print(f"{path} 不存在")

# os.makedirs(path) - 创建文件夹
if not os.path.exists(path):
    os.makedirs(path)
    print(f"创建文件夹: {path}")

# os.path.join(dir, filename) - 组合文件路径
filename = "news.txt"
filepath = os.path.join(path, filename)
print(f"文件路径: {filepath}")
# Out:
# data 不存在
# 创建文件夹: data
# 文件路径: data/news.txt

# %% [markdown]
# ## 5. 字符串方法

# %%
text = "  Hello: World/Test  "

# str.replace(old, new) - 替换字符
new_text = text.replace(":", "").replace("/", "")
print(f"替换后: {new_text}")

# str.strip() - 去除首尾空白字符
clean_text = new_text.strip()
print(f"去除空白: {clean_text}")

# len(str) - 获取字符串长度
print(f"长度: {len(clean_text)}")

# str[:50] - 字符串切片，取前50个字符
short_text = clean_text[:50]
print(f"前50字符: {short_text}")
# Out:
# 替换后:   Hello WorldTest
# 去除空白: Hello WorldTest
# 长度: 15
# 前50字符: Hello WorldTest

# %% [markdown]
# ## 6. 文件操作（内置函数）

# %%
# open(filepath, "w", encoding="utf-8") - 打开文件（写入模式）
filepath = "test.txt"
with open(filepath, "w", encoding="utf-8") as f:
    # f.write(text) - 写入内容
    f.write("第一行\n")
    f.write("第二行\n")

print(f"已写入文件: {filepath}")
